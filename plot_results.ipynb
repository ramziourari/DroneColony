# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from numpy import linspace
import matplotlib.path as mpath
import numpy as np
import matplotlib.cm as cm

# %%
import matplotlib.pyplot as plt

plt.rc('xtick',labelsize=18)
plt.rc('ytick',labelsize=18)
plt.rc('font', size=18)

# %%
IPython_default = plt.rcParams.copy()

# %%
from matplotlib import cycler
colors = cycler('color',
                ['#EE6666', '#3388BB', '#9988DD',
                 '#EECC55', '#88BB44', '#FFBBBB'])
plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',
       axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

# %%
df = pd.read_hdf("traj.h5")

# %%
coll = df[df.index == 6] * 212

# %%
coll.describe()
# Out:
#        DroneBrainColect?team=0_0  DroneBrainColect?team=0_1  \
# count                 208.000000                 208.000000
# mean                   20.257448                  24.689913
# std                     8.545942                   5.549101
# min                     8.262960                  12.482385
# 25%                    11.412581                  21.878453
# 50%                    21.449107                  25.445173
# 75%                    27.681978                  29.486296
# max                    33.383400                  31.831083
#
#        DroneBrainColect?team=0_2  DroneBrainColect?team=0_3
# count                 208.000000                 208.000000
# mean                   24.693874                  21.393711
# std                     8.141011                   9.607875
# min                     8.942081                   8.262960
# 25%                    18.069815                  11.126769
# 50%                    29.619145                  21.960397
# ...

# %%
dfs = [df_2, df_3, df_4, df_5, df_6, df_7,
       df_8, df_10, df_12]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-303c73e99af7> in <module>
# ----> 1 dfs = [df_2, df_3, df_4, df_5, df_6, df_7,
#       2        df_8, df_10, df_12]
#
# NameError: name 'df_2' is not defined

# %%
min_distances = []
avg_distances = []
for i in range(len(dfs)):
    test = dfs[i][dfs[i].index==6] * 212
    min_distances.append(test.min().min())
    avg_distances.append(test.min().mean())

# %%
agents = [2, 3, 4, 5, 6, 7, 8, 10, 12]

# %%
bins = np.arange(len(agents))
width = 0.3

# %%
dfs = [df_8, df_10, df_20]

# %%
fig2, axes = plt.subplots(nrows=1, ncols=3, figsize=(22, 8), sharex='col', sharey='row')
plt.tight_layout()
for i, ax in enumerate(axes.flatten()):
    x = dfs[i][dfs[i].index == 2] * 55
    y = dfs[i][dfs[i].index == 3] * 55
    num_colors = len(x.columns)
    cm_subsection = linspace(start, stop, num_colors) 
    colors = [ cm.Set1(x) for x in cm_subsection ]
    for l in range(len(x.columns)):
        for m in range(len(x)):
            ax.plot(x[x.columns[l]][m:m+2], y[y.columns[l]][m:m+2], 'o',
                    markersize=4, linewidth=7.0,
                    color=colors[l], alpha=(1-float(m)/len(x)))
    ax.set_xlabel('x (m)', fontsize = 25) # X label
    ax.set_ylabel('y (m)', fontsize = 25.0) # Y label
    plt.tight_layout()
# plt.savefig("traj_drones_81012.pdf")

# %%
fig2, axes = plt.subplots(nrows=1, ncols=3, figsize=(22, 8), sharex='col', sharey='row')
plt.tight_layout()
for i, ax in enumerate(axes.flatten()):
    y = dfs[i][dfs[i].index == 0] * 212
    x = np.arange(len(y.index)) * 20e-3
    for c in y.columns:
        ax.plot(x, y[c].values, label='agents')
        plt.tight_layout()
        ax.hlines(3.5, xmin=0, xmax=x[-1], colors='r')
    ax.set_xlabel('time (s)', fontsize = 25) # X label
    ax.set_ylabel('distance to target (m)', fontsize = 25.0) # Y label
    plt.tight_layout()
# plt.savefig("targ_drones_81012.pdf")

# %%
fig2, axes = plt.subplots(nrows=1, ncols=3, figsize=(22, 8), sharex='col', sharey='row')
plt.tight_layout()
for i, ax in enumerate(axes.flatten()):
    y = dfs[i][dfs[i].index == 6] * 212
    x = np.arange(len(y.index)) * 20e-3
    for c in y.columns:
        ax.plot(x, y[c].values)
        plt.tight_layout()
        ax.hlines(7, xmin=0, xmax=x[-1], colors='r')
    ax.set_xlabel('time (s)', fontsize = 25) # X label
    ax.set_ylabel('distance to nearest agent (m)', fontsize = 25.0) # Y label
    plt.tight_layout()
# plt.savefig("dis_drones_81012.pdf")

# %%
fig2, axes = plt.subplots(nrows=3, ncols=3, figsize=(20,8), sharex='col', sharey='row')
plt.tight_layout()
for i, ax in enumerate(axes.flatten()):
    x = dT = df[df[i].index == 0] * 212
    y = dfs[i][dfs[i].index == 3] * 55
    num_colors = len(x.columns)
    cm_subsection = linspace(start, stop, num_colors) 
    colors = [ cm.Set1(x) for x in cm_subsection ]
    for l in range(len(x.columns)):
        for m in range(len(x)):
            ax.plot(, '-',
                    markersize=4, linewidth=7.0,
                    color=colors[l])
    ax.set_xlabel('distance to target (m)', fontsize = 20) # X label
    ax.set_ylabel('time (s))', fontsize = 20.0) # Y label
    plt.tight_layout()
# plt.savefig("sub_drones_567.pdf")
# Out:
#   File "<ipython-input-1072-1553ff5cb78e>", line 11
#     ax.plot(, '-',
#             ^
# SyntaxError: invalid syntax

# %%
len(subset)
# Out:
# 451

# %%
subset.dropna(inplace=True)

# %%
subset
# Out:
# Empty DataFrame
# Columns: [DroneBrainColect?team=0_0, DroneBrainColect?team=0_1, DroneBrainColect?team=0_2, DroneBrainColect?team=0_3, DroneBrainColect?team=0_4, DroneBrainColect?team=0_5, DroneBrainColect?team=0_6, DroneBrainColect?team=0_7, DroneBrainColect?team=0_8, DroneBrainColect?team=0_9, DroneBrainColect?team=0_10, DroneBrainColect?team=0_11, DroneBrainColect?team=0_12, DroneBrainColect?team=0_13]
# Index: []

# %%
len(subset)
# Out:
# 0

# %%
(len(dT) - len(subset)) * 20e-3
# Out:
# 4.28

# %%
subset = dT[dT < 3.5]

# %%
subset
# Out:
#     DroneBrainColect?team=0_0  DroneBrainColect?team=0_1  \
# 0                         NaN                        NaN
# 0                         NaN                        NaN
# 0                         NaN                        NaN
# 0                         NaN                        NaN
# 0                         NaN                        NaN
# ..                        ...                        ...
# 0                    1.856696                   2.119704
# 0                    1.762324                   2.024019
# 0                    1.663099                   1.900416
# 0                    1.580779                   1.753693
# 0                    1.524167                   1.611598
#
#     DroneBrainColect?team=0_2  DroneBrainColect?team=0_3  \
# 0                         NaN                        NaN
# 0                         NaN                        NaN
# 0                         NaN                        NaN
# ...

# %%
subset = df[df.index == 6] * 212 < 7

# %%
subset
# Out:
#     DroneBrainColect?team=0_0  DroneBrainColect?team=0_1  \
# 6                       False                      False
# 6                       False                      False
# 6                       False                      False
# 6                       False                      False
# 6                       False                      False
# ..                        ...                        ...
# 6                       False                      False
# 6                       False                      False
# 6                       False                      False
# 6                       False                      False
# 6                       False                      False
#
#     DroneBrainColect?team=0_2  DroneBrainColect?team=0_3  \
# 6                       False                      False
# 6                       False                      False
# 6                       False                      False
# ...

# %%
dfs = []
for i in range(7):
    df = pd.read_hdf("traj_"+str(i+2)+".h5".format(i))
    dfs.append(df)

# %%
x = df[df.index == 2] * 55
y = df[df.index == 3] * 55

plt.figure(figsize=(14, 15))
start = 0.0
stop = 1.0
num_colors = len(x.columns)
cm_subsection = linspace(start, stop, num_colors) 
colors = [ cm.Set1(x) for x in cm_subsection ]


for j in range(len(x.columns)):
    for i in range(len(x)):
        plt.plot(x[x.columns[j]][i:i+2], y[y.columns[j]][i:i+2], '-',
                    markersize=4, linewidth=7.0,
                 color=colors[j], alpha=(1-float(i)/len(x)))
    plt.xlabel("x (m)")
    plt.ylabel("y (m)")
plt.tight_layout()
# plt.savefig("6_drones.pdf")

# %%
dfs = [df_8, df_10, df_12]

# %%
fig2, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,8), sharex='col', sharey='row')
plt.tight_layout()
for i, ax in enumerate(axes.flatten()):
    x = dfs[i][dfs[i].index == 2] * 55
    y = dfs[i][dfs[i].index == 3] * 55
    num_colors = len(x.columns)
    cm_subsection = linspace(start, stop, num_colors) 
    colors = [ cm.Set1(x) for x in cm_subsection ]
    for l in range(len(x.columns)):
        for m in range(len(x)):
            ax.plot(x[x.columns[l]][m:m+2], y[y.columns[l]][m:m+2], 'o',
                    markersize=4, linewidth=7.0,
                    color=colors[l], alpha=(1-float(m)/len(x)))
    ax.set_xlabel('x (m)', fontsize = 20) # X label
    ax.set_ylabel('y (m)', fontsize = 20.0) # Y label
    plt.tight_layout()
# plt.savefig("sub_drones_567.pdf")
